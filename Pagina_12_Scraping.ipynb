# %% [markdown]
# <a href="https://colab.research.google.com/github/santywin/web-scraping/blob/main/Pagina_12_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = 'https://elmercurio.com.ec/'

# %%
p12 = requests.get(url)

# %%
p12.status_code
# Out:
# 200

# %%
p12.text
# Out:
# '<!doctype html >\n<html lang="es">\n<head>\n<meta charset="UTF-8" />\n<title>Diario El Mercurio en Cuenca - Lea las Noticias en el Ecuador y del mundo</title>\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<link rel="pingback" href="https://elmercurio.com.ec/xmlrpc.php" />\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<link rel="icon" type="image/png" href="https://elmercurio.com.ec/wp-content/uploads/2021/06/fabicon-mercurio.jpg">\n\n<meta name="description" content="Diario El Mercurio Cuenca - Lea las Noticias en el Ecuador y del mundo, noticias de actualidad, sucesos, nacionales, deportes, política, etc." />\n<link rel="canonical" href="https://elmercurio.com.ec/" />\n<meta name="twitter:label1" content="Tiempo de lectura" />\n<meta name="twitter:data1" content="6 minutos" />\n<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@ty
# ...

# %%
p12.content
# Out:
# b'<!doctype html >\n<html lang="es">\n<head>\n<meta charset="UTF-8" />\n<title>Diario El Mercurio en Cuenca - Lea las Noticias en el Ecuador y del mundo</title>\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<link rel="pingback" href="https://elmercurio.com.ec/xmlrpc.php" />\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<link rel="icon" type="image/png" href="https://elmercurio.com.ec/wp-content/uploads/2021/06/fabicon-mercurio.jpg">\n\n<meta name="description" content="Diario El Mercurio Cuenca - Lea las Noticias en el Ecuador y del mundo, noticias de actualidad, sucesos, nacionales, deportes, pol\xc3\xadtica, etc." />\n<link rel="canonical" href="https://elmercurio.com.ec/" />\n<meta name="twitter:label1" content="Tiempo de lectura" />\n<meta name="twitter:data1" content="6 minutos" />\n<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph
# ...

# %%
p12.headers
# Out:
# {'Date': 'Thu, 28 Apr 2022 18:56:34 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'vary': 'Accept-Encoding', 'accept-ch': 'Sec-CH-UA-Mobile', 'Cache-Control': 'no-cache', 'x-nitro-cache': 'MISS', 'x-nitro-disabled': '1', 'x-nitro-disabled-reason': 'url not allowed', 'link': '<https://elmercurio.com.ec/wp-json/>; rel="https://api.w.org/", <https://elmercurio.com.ec/wp-json/wp/v2/pages/876598>; rel="alternate"; type="application/json", <https://elmercurio.com.ec/>; rel=shortlink', 'content-security-policy': 'upgrade-insecure-requests', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'x-nginx-upstream-cache-status': 'EXPIRED', 'x-server-powered-by': 'Engintron', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=fEPT5Cc1SM3xtgfiRBCOG
# ...

# %%
p12.request.headers
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
p12.request.method
# Out:
# 'GET'

# %%
p12.request.url
# Out:
# 'https://elmercurio.com.ec/'

# %%
 from bs4 import BeautifulSoup

# %%
s = BeautifulSoup(p12.text, 'lxml')

# %% [markdown]
# print(s.prettify())

# %%
type(s)
# Out:
# bs4.BeautifulSoup

# %%
secciones = s.find('ul', attrs={"id":"menu-menu-principal-1"}).find_all('li')

# %%
print(secciones)
# Out:
# [<li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home current-menu-item page_item page-item-876598 current_page_item menu-item-first tdb-menu-item-button tdb-menu-item tdb-normal-menu menu-item-876633"><a href="https://elmercurio.com.ec/"><div class="tdb-menu-item-text">Inicio</div></a></li>, <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children tdb-menu-item-button tdb-menu-item tdb-normal-menu menu-item-868424 tdb-menu-item-inactive"><a href="https://elmercurio.com.ec/category/cuenca/"><div class="tdb-menu-item-text">Cuenca</div><i class="tdb-sub-menu-icon td-icon-down tdb-main-sub-menu-icon"></i></a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category tdb-menu-item tdb-normal-menu menu-item-954545"><a href="https://elmercurio.com.ec/category/cuenca/cultura/"><div class="tdb-menu-item-text">Cultura</div></a></li>
# </ul>
# ...

# %%
seccion = secciones[0]

# %%
print(seccion.find('a'))
# Out:
# <a href="https://elmercurio.com.ec/"><div class="tdb-menu-item-text">Inicio</div></a>

# %%
print(seccion.a.get_text())
# Out:
# Inicio

# %%
print(secciones[4].get_text())
# Out:
# Nacional

# %%
print(seccion.a.get('href'))
# Out:
# https://elmercurio.com.ec/

# %%
print(secciones[0].a.get('href'))
# Out:
# https://elmercurio.com.ec/

# %%
links_secciones = {seccion.a.get('href') for seccion in secciones }

# %%
print(links_secciones)
# Out:
# {'https://elmercurio.com.ec/category/cuenca/cultura/', 'https://elmercurio.com.ec/category/servicios/suplementos/', 'https://elmercurio.com.ec/category/servicios/', 'https://elmercurio.com.ec/category/servicios/anun-clasif/', 'https://elmercurio.com.ec/', 'https://elmercurio.com.ec/category/opinion/', 'https://elmercurio.com.ec/category/servicios/sociales/', 'https://elmercurio.com.ec/category/region/', 'https://elmercurio.com.ec/category/actualidad/nacional/', 'https://elmercurio.com.ec/category/opinion/caricaturas/', 'https://elmercurio.com.ec/category/mundo-noticias/', 'https://elmercurio.com.ec/category/deportes/', 'https://www.clasificadoselmercurio.com.ec/', 'https://elmercurio.com.ec/category/opinion/editorial/', 'https://elmercurio.com.ec/category/opinion/columnistas/', 'https://elmercurio.com.ec/category/servicios/defunciones/', 'https://elmercurio.com.ec/category/cuenca/', 'https://elmercurio.com.ec/category/deportes/deportivo-cuenca/'}

# %%
type(links_secciones)
# Out:
# set

# %%
mylist = [x for x in links_secciones]

# %%
type(mylist)
# Out:
# list

# %%
print(mylist)
# Out:
# ['https://elmercurio.com.ec/category/cuenca/cultura/', 'https://elmercurio.com.ec/category/servicios/suplementos/', 'https://elmercurio.com.ec/category/servicios/', 'https://elmercurio.com.ec/category/servicios/anun-clasif/', 'https://elmercurio.com.ec/', 'https://elmercurio.com.ec/category/opinion/', 'https://elmercurio.com.ec/category/servicios/sociales/', 'https://elmercurio.com.ec/category/region/', 'https://elmercurio.com.ec/category/actualidad/nacional/', 'https://elmercurio.com.ec/category/opinion/caricaturas/', 'https://elmercurio.com.ec/category/mundo-noticias/', 'https://elmercurio.com.ec/category/deportes/', 'https://www.clasificadoselmercurio.com.ec/', 'https://elmercurio.com.ec/category/opinion/editorial/', 'https://elmercurio.com.ec/category/opinion/columnistas/', 'https://elmercurio.com.ec/category/servicios/defunciones/', 'https://elmercurio.com.ec/category/cuenca/', 'https://elmercurio.com.ec/category/deportes/deportivo-cuenca/']

# %%
sec = requests.get(mylist[0])

# %%
print(sec)
# Out:
# <Response [200]>

# %%
sec = requests.get(mylist[0])

# %%
mylist[0]
# Out:
# 'https://elmercurio.com.ec/category/cuenca/cultura/'

# %%
sec.status_code
# Out:
# 200

# %%
print(sec)
# Out:
# <Response [200]>

# %%
noti = BeautifulSoup(sec.text, 'lxml')

# %%
featured_article = noti.find('div', attrs={'class':'td-ss-main-content'})

# %%
featured_article.a.get('href')
# Out:
# 'https://elmercurio.com.ec/2022/04/18/la-escritora-mariagusta-correa-lanza-su-nuevo-libro-%ce%adpsilon/'

# %%
article_list = noti.find('div', attrs={'class':'td-block-span6'})

# %%
article_list.prettify
# Out:
# <bound method Tag.prettify of <div class="td-block-span6">
# <div class="td_module_1 td_module_wrap clearfix post-958339 post type-post status-publish format-standard has-post-thumbnail category-cultura">
# <div class="td-module-image">
# <div class="td-module-thumb">
# <a class="td-image-wrap" href="https://elmercurio.com.ec/2022/04/18/la-escritora-mariagusta-correa-lanza-su-nuevo-libro-%ce%adpsilon/" rel="bookmark" title="La escritora Mariagusta Correa lanza su nuevo libro “έpsilon”">
# <img alt="La escritora Mariagusta Correa lanza su nuevo libro “έpsilon”" class="entry-thumb" src="https://elmercurio.com.ec/wp-content/uploads/2022/04/IMG-0343-768x740.jpg" title="La escritora Mariagusta Correa lanza su nuevo libro “έpsilon”"/>
# </a>
# </div>
# <a class="td-post-category" href="https://elmercurio.com.ec/category/cuenca/cultura/">Cultura</a>
# </div>
# <h3 class="entry-title td-module-title">
# ...

# %%
fecha = article_list.find('time', attrs={'class':'entry-date updated td-module-date'})

# %%
print(fecha.get('datetime'))
# Out:
# 2022-04-18T12:12:10+00:00

# %%
art = requests.get('https://elmercurio.com.ec/2022/04/18/la-escritora-mariagusta-correa-lanza-su-nuevo-libro-%ce%adpsilon/')

# %%
artb = BeautifulSoup(art.text, 'lxml')

# %%
title = artb.find('h1', attrs={'class':'entry-title'})

# %%
print(title.text  )
# Out:
# La escritora Mariagusta Correa lanza su nuevo libro “έpsilon”
